# %% [markdown]
# <a href="https://colab.research.google.com/github/BHAVATHARININ/ML-PANDAS/blob/main/SP_ML_PANDAS_13_10_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **WHAT IS PANDAS ?**
#
# Functionalities are more than SQL
#
# POLARS - Similar to Pandas, which are used mainly for big data
#
# Python is a software library written in python for data manipulation and analysis. It offers data structures and operations for manipulating tables and time series

# %% [markdown]
# Roboflow - Used for data annotation

# %% [markdown]
# **SERIES**
#
# One dimensional and dataframe is 2 dimensional

# %% [markdown]
# **Difference for Numpy and Pandas**
#
# In numpy only index can be used to access whereas in pandas both rows and columns can be used to sccess the values

# %% [markdown]
# Dfrnce btween CPU & GPU
#
# https://www.geeksforgeeks.org/difference-between-cpu-and-gpu/

# %%
import numpy as np
import pandas as pd

# %%
a = np.array([10,20,30,40,50])
a
# Out:
# array([10, 20, 30, 40, 50])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a[1]
# Out:
# 20

# %%
b = pd.Series([10,20,30,40,50]) #Series is a 1 dimensional data
b
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
type(b)
# Out:
# pandas.core.series.Series

# %%
b[3]
# Out:
# 40

# %%
b.drop(1, inplace = True)

# %%
b.iloc[3] #By using Indexing Series value allocated by it
# Out:
# 50

# %%
b
# Out:
# 0    10
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
c = pd.Series([100,200,300,400,500], index=['a', 'b','c','e','e'])#giving values for indexex
c
# Out:
# a    100
# b    200
# c    300
# e    400
# e    500
# dtype: int64

# %%
c.loc['e'] #using values in series of numbers created by series
# Out:
# e    400
# e    500
# dtype: int64

# %%
c.iloc[2] #using the internal index of created series
# Out:
# 300

# %% [markdown]
# **DATAFTRAME**

# %%
data = [['Bhava', 19, '07-03-2004'], ['Promoth', 20, '18-09-2003'], ['Tharshini', 20, '24-09-2003'], ['Sowrabha', 19, '20-10-2003'], ['Kaviya', None, '9-10-2003'], ['Booma', 19, None],['Bob',None,None], ['Clarke', None, '10-10-2003'], ['Nivi', None, None],['Dharshana' , 20, '5-5-2004']]

# %%
data
# Out:
# [['Bhava', 19, '07-03-2004'],
#  ['Promoth', 20, '18-09-2003'],
#  ['Tharshini', 20, '24-09-2003'],
#  ['Sowrabha', 19, '20-10-2003'],
#  ['Kaviya', None, '9-10-2003'],
#  ['Booma', 19, None],
#  ['Bob', None, None],
#  ['Clarke', None, '10-10-2003'],
#  ['Nivi', None, None],
#  ['Dharshana', 20, '5-5-2004']]

# %%
df = pd.DataFrame(data)
df
# Out:
#            0     1           2
# 0      Bhava  19.0  07-03-2004
# 1    Promoth  20.0  18-09-2003
# 2  Tharshini  20.0  24-09-2003
# 3   Sowrabha  19.0  20-10-2003
# 4     Kaviya   NaN   9-10-2003
# 5      Booma  19.0        None
# 6        Bob   NaN        None
# 7     Clarke   NaN  10-10-2003
# 8       Nivi   NaN        None
# 9  Dharshana  20.0    5-5-2004

# %%
df[0:1]
# Out:
#        0     1           2
# 0  Bhava  19.0  07-03-2004

# %%
df[0:2]
# Out:
#          0     1           2
# 0    Bhava  19.0  07-03-2004
# 1  Promoth  20.0  18-09-2003

# %%
df[0:3]
# Out:
#            0     1           2
# 0      Bhava  19.0  07-03-2004
# 1    Promoth  20.0  18-09-2003
# 2  Tharshini  20.0  24-09-2003

# %%
df[0][0]
# Out:
# 'Bhava'

# %%
df[[0,2]] #gives 0 and 2 column
# Out:
#            0           2
# 0      Bhava  07-03-2004
# 1    Promoth  18-09-2003
# 2  Tharshini  24-09-2003
# 3   Sowrabha  20-10-2003
# 4     Kaviya   9-10-2003
# 5      Booma        None
# 6        Bob        None
# 7     Clarke  10-10-2003
# 8       Nivi        None
# 9  Dharshana    5-5-2004

# %%
df[0][3]
# Out:
# 'Sowrabha'

# %%
df = pd.DataFrame(data, columns = ['First Name','Age','DOB'])

# %%
df
# Out:
#   First Name   Age         DOB
# 0      Bhava  19.0  07-03-2004
# 1    Promoth  20.0  18-09-2003
# 2  Tharshini  20.0  24-09-2003
# 3   Sowrabha  19.0  20-10-2003
# 4     Kaviya   NaN   9-10-2003
# 5      Booma  19.0        None
# 6        Bob   NaN        None
# 7     Clarke   NaN  10-10-2003
# 8       Nivi   NaN        None
# 9  Dharshana  20.0    5-5-2004

# %%
df['First Name']
# Out:
# 0        Bhava
# 1      Promoth
# 2    Tharshini
# 3     Sowrabha
# 4       Kaviya
# 5        Booma
# 6          Bob
# 7       Clarke
# 8         Nivi
# 9    Dharshana
# Name: First Name, dtype: object

# %%
df['Age']
# Out:
# 0    19.0
# 1    20.0
# 2    20.0
# 3    19.0
# 4     NaN
# 5    19.0
# 6     NaN
# 7     NaN
# 8     NaN
# 9    20.0
# Name: Age, dtype: float64

# %%
df['First Name'][1]
# Out:
# 'Promoth'

# %%
df.loc[0, 'First Name']
# Out:
# 'Bhava'

# %%
df.iloc[1,0]
# Out:
# 'Promoth'

# %%
d = pd.Series([1,2,3,4,5])
d
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
d.plot()
# Out:
# <Axes: >

# %%
type(d)
# Out:
# pandas.core.series.Series

# %%
d = d.to_numpy()

# %%
type(d)
# Out:
# numpy.ndarray

# %%
df.head()
# Out:
#   First Name   Age         DOB
# 0      Bhava  19.0  07-03-2004
# 1    Promoth  20.0  18-09-2003
# 2  Tharshini  20.0  24-09-2003
# 3   Sowrabha  19.0  20-10-2003
# 4     Kaviya   NaN   9-10-2003

# %%
df.head(1)
# Out:
#   First Name   Age         DOB
# 0      Bhava  19.0  07-03-2004

# %%
df.tail(1)
# Out:
#   First Name   Age       DOB
# 9  Dharshana  20.0  5-5-2004

# %%
df.tail(-2)
# Out:
#   First Name   Age         DOB
# 2  Tharshini  20.0  24-09-2003
# 3   Sowrabha  19.0  20-10-2003
# 4     Kaviya   NaN   9-10-2003
# 5      Booma  19.0        None
# 6        Bob   NaN        None
# 7     Clarke   NaN  10-10-2003
# 8       Nivi   NaN        None
# 9  Dharshana  20.0    5-5-2004

# %% [markdown]
# None, ' ',  '' ,  '-',  'Nil',  np.nan (Not a Number)

# %%
df
# Out:
#   First Name   Age         DOB
# 0      Bhava  19.0  07-03-2004
# 1    Promoth  20.0  18-09-2003
# 2  Tharshini  20.0  24-09-2003
# 3   Sowrabha  19.0  20-10-2003
# 4     Kaviya   NaN   9-10-2003
# 5      Booma  19.0        None
# 6        Bob   NaN        None
# 7     Clarke   NaN  10-10-2003
# 8       Nivi   NaN        None
# 9  Dharshana  20.0    5-5-2004

# %%
df.isnull()
# Out:
#    First Name    Age    DOB
# 0       False  False  False
# 1       False  False  False
# 2       False  False  False
# 3       False  False  False
# 4       False   True  False
# 5       False  False   True
# 6       False   True   True
# 7       False   True  False
# 8       False   True   True
# 9       False  False  False

# %%
df.isna().sum()
# Out:
# First Name    0
# Age           4
# DOB           3
# dtype: int64

# %%
df.dropna()
# Out:
#   First Name   Age         DOB
# 0      Bhava  19.0  07-03-2004
# 1    Promoth  20.0  18-09-2003
# 2  Tharshini  20.0  24-09-2003
# 3   Sowrabha  19.0  20-10-2003
# 9  Dharshana  20.0    5-5-2004

# %%
df
# Out:
#   First Name   Age         DOB
# 0      Bhava  19.0  07-03-2004
# 1    Promoth  20.0  18-09-2003
# 2  Tharshini  20.0  24-09-2003
# 3   Sowrabha  19.0  20-10-2003
# 4     Kaviya   NaN   9-10-2003
# 5      Booma  19.0        None
# 6        Bob   NaN        None
# 7     Clarke   NaN  10-10-2003
# 8       Nivi   NaN        None
# 9  Dharshana  20.0    5-5-2004

# %%
df
# Out:
#   First Name   Age         DOB
# 0      Bhava  19.0  07-03-2004
# 1    Promoth  20.0  18-09-2003
# 2  Tharshini  20.0  24-09-2003
# 3   Sowrabha  19.0  20-10-2003
# 4     Kaviya   NaN   9-10-2003
# 5      Booma  19.0        None
# 6        Bob   NaN        None
# 7     Clarke   NaN  10-10-2003
# 8       Nivi   NaN        None
# 9  Dharshana  20.0    5-5-2004

# %%
df.drop([5,7])
# Out:
#   First Name   Age         DOB
# 0      Bhava  19.0  07-03-2004
# 1    Promoth  20.0  18-09-2003
# 2  Tharshini  20.0  24-09-2003
# 3   Sowrabha  19.0  20-10-2003
# 4     Kaviya   NaN   9-10-2003
# 6        Bob   NaN        None
# 8       Nivi   NaN        None
# 9  Dharshana  20.0    5-5-2004

# %%
a1 = np.array([10,11,12,20,21,22,30,31,32,40,41,42,50,51,52])

# %%
a1[a1 > 30]
# Out:
# array([31, 32, 40, 41, 42, 50, 51, 52])

# %%
a1[a1 % 2 != 0]
# Out:
# array([11, 21, 31, 41, 51])

# %%
a1[a1 % 2 == 0]
# Out:
# array([10, 12, 20, 22, 30, 32, 40, 42, 50, 52])

# %%
df
# Out:
#   First Name   Age         DOB
# 0      Bhava  19.0  07-03-2004
# 1    Promoth  20.0  18-09-2003
# 2  Tharshini  20.0  24-09-2003
# 3   Sowrabha  19.0  20-10-2003
# 4     Kaviya   NaN   9-10-2003
# 5      Booma  19.0        None
# 6        Bob   NaN        None
# 7     Clarke   NaN  10-10-2003
# 8       Nivi   NaN        None
# 9  Dharshana  20.0    5-5-2004

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  10 non-null     object
#  1   Age         6 non-null      float64
#  2   DOB         7 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 368.0+ bytes

# %%
df['First Name'].str.contains('e')
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7     True
# 8    False
# 9    False
# Name: First Name, dtype: bool

# %%
df['First Name'].str.contains('b')
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7    False
# 8    False
# 9    False
# Name: First Name, dtype: bool

# %%
df['First Name'].str.contains('B')
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# 7    False
# 8    False
# 9    False
# Name: First Name, dtype: bool

# %%
print(df.shape)
# Out:
# (10, 3)

# %%
print(df.size)
# Out:
# 30

# %%
print(df.axes)
# Out:
# [RangeIndex(start=0, stop=10, step=1), Index(['First Name', 'Age', 'DOB'], dtype='object')]

# %%
print(df.ndim)
# Out:
# 2

# %%
print(df.dtypes)
# Out:
# First Name     object
# Age           float64
# DOB            object
# dtype: object

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
print(df.columns)
# Out:
# Index(['First Name', 'Age', 'DOB'], dtype='object')

# %%
print(df.values)
# Out:
# [['Bhava' 19.0 '07-03-2004']
#  ['Promoth' 20.0 '18-09-2003']
#  ['Tharshini' 20.0 '24-09-2003']
#  ['Sowrabha' 19.0 '20-10-2003']
#  ['Kaviya' nan '9-10-2003']
#  ['Booma' 19.0 None]
#  ['Bob' nan None]
#  ['Clarke' nan '10-10-2003']
#  ['Nivi' nan None]
#  ['Dharshana' 20.0 '5-5-2004']]

# %%
df.head()
# Out:
#   First Name   Age         DOB
# 0      Bhava  19.0  07-03-2004
# 1    Promoth  20.0  18-09-2003
# 2  Tharshini  20.0  24-09-2003
# 3   Sowrabha  19.0  20-10-2003
# 4     Kaviya   NaN   9-10-2003

# %%
df.tail()
# Out:
#   First Name   Age         DOB
# 5      Booma  19.0        None
# 6        Bob   NaN        None
# 7     Clarke   NaN  10-10-2003
# 8       Nivi   NaN        None
# 9  Dharshana  20.0    5-5-2004

# %%
df1 = pd.concat([df, df])

# %%
df1
# Out:
#   First Name   Age         DOB
# 0      Bhava  19.0  07-03-2004
# 1    Promoth  20.0  18-09-2003
# 2  Tharshini  20.0  24-09-2003
# 3   Sowrabha  19.0  20-10-2003
# 4     Kaviya   NaN   9-10-2003
# 5      Booma  19.0        None
# 6        Bob   NaN        None
# 7     Clarke   NaN  10-10-2003
# 8       Nivi   NaN        None
# 9  Dharshana  20.0    5-5-2004
# 0      Bhava  19.0  07-03-2004
# 1    Promoth  20.0  18-09-2003
# 2  Tharshini  20.0  24-09-2003
# 3   Sowrabha  19.0  20-10-2003
# 4     Kaviya   NaN   9-10-2003
# 5      Booma  19.0        None
# 6        Bob   NaN        None
# 7     Clarke   NaN  10-10-2003
# 8       Nivi   NaN        None
# 9  Dharshana  20.0    5-5-2004

# %%
df.describe(include = "all")
# Out:
#        First Name        Age         DOB
# count          10   6.000000           7
# unique         10        NaN           7
# top         Bhava        NaN  07-03-2004
# freq            1        NaN           1
# mean          NaN  19.500000         NaN
# std           NaN   0.547723         NaN
# min           NaN  19.000000         NaN
# 25%           NaN  19.000000         NaN
# 50%           NaN  19.500000         NaN
# 75%           NaN  20.000000         NaN
# max           NaN  20.000000         NaN

# %%
df['First Name']
# Out:
# 0        Bhava
# 1      Promoth
# 2    Tharshini
# 3     Sowrabha
# 4       Kaviya
# 5        Booma
# 6          Bob
# 7       Clarke
# 8         Nivi
# 9    Dharshana
# Name: First Name, dtype: object

# %%
df.DOB
# Out:
# 0    07-03-2004
# 1    18-09-2003
# 2    24-09-2003
# 3    20-10-2003
# 4     9-10-2003
# 5          None
# 6          None
# 7    10-10-2003
# 8          None
# 9      5-5-2004
# Name: DOB, dtype: object

# %%
df.DOB[0]
# Out:
# '07-03-2004'

# %%
df[['First Name', 'Age']]
# Out:
#   First Name   Age
# 0      Bhava  19.0
# 1    Promoth  20.0
# 2  Tharshini  20.0
# 3   Sowrabha  19.0
# 4     Kaviya   NaN
# 5      Booma  19.0
# 6        Bob   NaN
# 7     Clarke   NaN
# 8       Nivi   NaN
# 9  Dharshana  20.0

# %%
df.loc[0][0]
# Out:
# 'Bhava'

# %%
df.loc[1,'First Name']
# Out:
# 'Promoth'

# %%
df.iloc[0,0]
# Out:
# 'Bhava'

# %%
df.iloc[0,1]
# Out:
# 19.0

# %%
df['DOB'][1] = '18-09-2004'
# Out:
# <ipython-input-76-20aaa7b55fb6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DOB'][1] = '18-09-2004'

# %%
df
# Out:
#   First Name   Age         DOB
# 0      Bhava  19.0  07-03-2004
# 1    Promoth  20.0  18-09-2004
# 2  Tharshini  20.0  24-09-2003
# 3   Sowrabha  19.0  20-10-2003
# 4     Kaviya   NaN   9-10-2003
# 5      Booma  19.0        None
# 6        Bob   NaN        None
# 7     Clarke   NaN  10-10-2003
# 8       Nivi   NaN        None
# 9  Dharshana  20.0    5-5-2004

# %%
df.loc[1,'DOB']
# Out:
# '18-09-2004'

# %% [markdown]
# READING FROM FILES
#
# 1.   CSV
# 2.   EXCEL

# %%
d = pd.read_html("https://en.wikipedia.org/wiki/List_of_highest-grossing_films")

# %%
d
# Out:
# [    Rank  Peak                                          Title  \
#  0      1     1                                         Avatar
#  1      2     1                              Avengers: Endgame
#  2      3     3                       Avatar: The Way of Water
#  3      4     1                                        Titanic
#  4      5     3                   Star Wars: The Force Awakens
#  5      6     4                         Avengers: Infinity War
#  6      7     6                        Spider-Man: No Way Home
#  7      8     3                                 Jurassic World
#  8      9     7                                  The Lion King
#  9     10     3                                   The Avengers
#  10    11     4                                      Furious 7
#  11    12    11                              Top Gun: Maverick
#  12    13    10                                      Frozen II
#  13    14    14                                       Barbie †
# ...

# %%
e = pd.read_table("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/chipotle.tsv")

# %%
e.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
e.isnull()
# Out:
#       order_id  quantity  item_name  choice_description  item_price
# 0        False     False      False                True       False
# 1        False     False      False               False       False
# 2        False     False      False               False       False
# 3        False     False      False                True       False
# 4        False     False      False               False       False
# ...        ...       ...        ...                 ...         ...
# 4617     False     False      False               False       False
# 4618     False     False      False               False       False
# 4619     False     False      False               False       False
# 4620     False     False      False               False       False
# 4621     False     False      False               False       False
#
# [4622 rows x 5 columns]

# %%
e.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
e.item_price = e.item_price.replace('$','')
e.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN      2.39
# 1                                       [Clementine]      3.39
# 2                                            [Apple]      3.39
# ...

# %%
type(e['item_price'][0])
# Out:
# str

# %%
e['item_price'] = e['item_price'].astype(float)

# %%
e
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
type(e['item_price'][0])
# Out:
# numpy.float64

# %%
e.item_price = (e.item_price ) * 100

# %%
e.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description  item_price
# 0                                                NaN       239.0
# 1                                       [Clementine]       339.0
# 2                                            [Apple]       339.0
# ...

# %%
e['item_name'].unique()
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Chips and Tomatillo Green Chili Salsa',
#        'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl', 'Steak Bowl',
#        'Barbacoa Soft Tacos', 'Veggie Burrito', 'Veggie Bowl',
#        'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Carnitas Soft Tacos',
#        'Chicken Salad', 'Canned Soft Drink', 'Steak Salad Bowl',
#        '6 Pack Soft Drink', 'Chips and Tomatillo-Red Chili Salsa', 'Bowl',
# ...

# %%
e_drink = e[e.item_price < 200]

# %%
e
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN       239.0
# ...

# %%
e_drink
# Out:
#       order_id  quantity          item_name choice_description  item_price
# 6            3         1      Side of Chips                NaN       169.0
# 28          14         1        Canned Soda       [Dr. Pepper]       109.0
# 32          16         1      Side of Chips                NaN       169.0
# 34          17         1      Bottled Water                NaN       109.0
# 53          24         1        Canned Soda           [Sprite]       109.0
# ...        ...       ...                ...                ...         ...
# 4598      1826         1      Bottled Water                NaN       150.0
# 4601      1827         1  Canned Soft Drink        [Diet Coke]       125.0
# 4606      1828         1  Canned Soft Drink             [Coke]       125.0
# 4609      1829         1  Canned Soft Drink           [Sprite]       125.0
# 4614      1831         1      Bottled Water                NaN       150.0
#
# [587 rows x 5 columns]

# %%
e_drink.item_name.unique()
# Out:
# array(['Side of Chips', 'Canned Soda', 'Bottled Water',
#        'Canned Soft Drink', 'Chips'], dtype=object)

# %%
e_drink.item_name.nunique()
# Out:
# 5

# %%
e_drink.item_name.value_counts()
# Out:
# Canned Soft Drink    264
# Bottled Water        139
# Side of Chips         99
# Canned Soda           84
# Chips                  1
# Name: item_name, dtype: int64

# %%
e
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN       239.0
# ...

# %%
e[e.item_name == 'Chicken Bowl']
# Out:
#       order_id  quantity     item_name  \
# 4            2         2  Chicken Bowl
# 5            3         1  Chicken Bowl
# 13           7         1  Chicken Bowl
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# ...        ...       ...           ...
# 4590      1825         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...      1698.0
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...      1098.0
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...      1125.0
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...       875.0
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...       849.0
# ...                                                 ...         ...
# ...

# %%
e[e.item_name == 'Steak Burrito']
# Out:
#       order_id  quantity      item_name  \
# 7            4         1  Steak Burrito
# 9            5         1  Steak Burrito
# 31          16         1  Steak Burrito
# 43          20         1  Steak Burrito
# 46          21         1  Steak Burrito
# ...        ...       ...            ...
# 4546      1807         1  Steak Burrito
# 4607      1829         1  Steak Burrito
# 4610      1830         1  Steak Burrito
# 4617      1833         1  Steak Burrito
# 4618      1833         1  Steak Burrito
#
#                                      choice_description  item_price
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...      1175.0
# 9     [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...       925.0
# 31    [[Roasted Chili Corn Salsa (Medium), Fresh Tom...       899.0
# 43    [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...      1175.0
# 46    [Tomatillo-Red Chili Salsa (Hot), [Rice, Fajit...       899.0
# ...                                                 ...         ...
# ...

# %%
e[e.item_name == 'Steak Burrito']['choice_description'].value_counts()
# Out:
# [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice, Cheese, Sour Cream]]                                                        12
# [Roasted Chili Corn Salsa (Medium), [Rice, Fajita Veggies, Cheese, Sour Cream, Lettuce]]                                     6
# [Tomatillo Green Chili Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream, Lettuce]]                                        6
# [[Roasted Chili Corn Salsa (Medium), Tomatillo-Red Chili Salsa (Hot)], [Black Beans, Rice, Cheese, Sour Cream, Lettuce]]     5
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]                                            5
#                                                                                                                             ..
# [Fresh Tomato Salsa, [Rice, Fajita Vegetables, Black Beans, Sour Cream, Cheese, Lettuce]]                                    1
# ...

# %%
e[e.item_name == 'Steak Burrito']['choice_description']
# Out:
# 7       [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# 9       [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...
# 31      [[Roasted Chili Corn Salsa (Medium), Fresh Tom...
# 43      [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...
# 46      [Tomatillo-Red Chili Salsa (Hot), [Rice, Fajit...
#                               ...
# 4546    [Fresh Tomato Salsa, [Rice, Black Beans, Cheese]]
# 4607    [Tomatillo Green Chili Salsa, [Rice, Cheese, S...
# 4610    [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...
# 4617    [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...
# 4618    [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...
# Name: choice_description, Length: 368, dtype: object

# %%
e[e.item_name == 'Steak Burrito']['choice_description'].nunique()
# Out:
# 251

# %%
e.dropna(inplace = True)

# %%
e
# Out:
#       order_id  quantity           item_name  \
# 1            1         1                Izze
# 2            1         1    Nantucket Nectar
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# ...        ...       ...                 ...
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price
# 1                                          [Clementine]       339.0
# 2                                               [Apple]       339.0
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...      1698.0
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...      1098.0
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...      1175.0
# ...

# %%
e[e.choice_description.str.contains('Black Beans')].item_name
# Out:
# 4               Chicken Bowl
# 7              Steak Burrito
# 9              Steak Burrito
# 11      Chicken Crispy Tacos
# 12        Chicken Soft Tacos
#                 ...
# 4604            Chicken Bowl
# 4608          Veggie Burrito
# 4611          Veggie Burrito
# 4612           Carnitas Bowl
# 4617           Steak Burrito
# Name: item_name, Length: 1345, dtype: object

# %%
e[e.choice_description.str.contains('Black Beans')].item_name.value_counts()
# Out:
# Chicken Bowl             386
# Chicken Burrito          282
# Steak Burrito            148
# Steak Bowl               110
# Veggie Bowl               60
# Veggie Burrito            55
# Chicken Salad Bowl        49
# Carnitas Bowl             39
# Barbacoa Bowl             37
# Barbacoa Burrito          30
# Carnitas Burrito          28
# Chicken Soft Tacos        19
# Chicken Crispy Tacos      14
# Veggie Salad Bowl         13
# Steak Salad Bowl          13
# Steak Soft Tacos          10
# Carnitas Soft Tacos        7
# Chicken Salad              7
# Veggie Soft Tacos          6
# Barbacoa Soft Tacos        6
# Veggie Salad               5
# Barbacoa Salad Bowl        4
# Barbacoa Crispy Tacos      3
# Carnitas Crispy Tacos      3
# Carnitas Salad Bowl        3
# Steak Crispy Tacos         2
# Steak Salad                2
# Salad                      2
# Burrito                    1
# Carnitas Salad             1
# Name: item_name, dtype: int64

# %%
e[(e['item_price'] < 1500) & (e['item_name'] == 'Chicken Bowl')]
# Out:
#       order_id  quantity     item_name  \
# 5            3         1  Chicken Bowl
# 13           7         1  Chicken Bowl
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# 42          20         1  Chicken Bowl
# ...        ...       ...           ...
# 4590      1825         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...      1098.0
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...      1125.0
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...       875.0
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...       849.0
# 42    [Roasted Chili Corn Salsa, [Rice, Black Beans,...      1125.0
# ...                                                 ...         ...
# ...

# %%
e[(e['item_price'] < 1500) & (e['item_name'] == 'Chicken Bowl')].sort_values('item_price')
# Out:
#       order_id  quantity     item_name  \
# 3664      1466         1  Chicken Bowl
# 2918      1160         1  Chicken Bowl
# 3101      1237         1  Chicken Bowl
# 934        385         1  Chicken Bowl
# 937        386         1  Chicken Bowl
# ...        ...       ...           ...
# 3655      1461         1  Chicken Bowl
# 1629       657         1  Chicken Bowl
# 2646      1051         1  Chicken Bowl
# 765        316         1  Chicken Bowl
# 3868      1551         1  Chicken Bowl
#
#                                      choice_description  item_price
# 3664  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...       819.0
# 2918  [Fresh Tomato (Mild), [Rice, Sour Cream, Cheese]]       819.0
# 3101  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...       819.0
# 934   [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice...       849.0
# 937   [Tomatillo-Red Chili Salsa (Hot), [Rice, Fajit...       849.0
# ...                                                 ...         ...
# ...

# %% [markdown]
# DATASET 2

# %%
movies= pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/imdb_1000.csv")

# %%
movies
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   star_rating     979 non-null    float64
#  1   title           979 non-null    object
#  2   content_rating  976 non-null    object
#  3   genre           979 non-null    object
#  4   duration        979 non-null    int64
#  5   actors_list     979 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.0+ KB

# %%
movies.isnull().sum()
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %%
movies[(movies.star_rating >= 8) & (movies.genre == "Action")]
# Out:
#      star_rating                                           title  \
# 3            9.0                                 The Dark Knight
# 11           8.8                                       Inception
# 12           8.8  Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                       Star Wars
# 20           8.7                                      The Matrix
# 36           8.6                             Saving Private Ryan
# 37           8.6                         Raiders of the Lost Ark
# 43           8.5                           The Dark Knight Rises
# 44           8.5                                       Gladiator
# 45           8.5                      Terminator 2: Judgment Day
# 75           8.4                                          Aliens
# 80           8.4      Star Wars: Episode VI - Return of the Jedi
# 82           8.4                                      Braveheart
# ...

# %%
movies[(movies.star_rating >= 8) & (movies.genre == "Action")].sort_values(['duration','star_rating'])
# Out:
#      star_rating                                           title  \
# 276          8.1                            A Fistful of Dollars
# 327          8.0                    The Adventures of Robin Hood
# 235          8.1                                         Yip Man
# 281          8.1                                  The Terminator
# 123          8.3                                     The General
# 96           8.4                                         Yojimbo
# 198          8.1                               Kill Bill: Vol. 1
# 349          8.0                                      District 9
# 391          8.0                                Edge of Tomorrow
# 239          8.1                   Elite Squad: The Enemy Within
# 240          8.1                            The Bourne Ultimatum
# 261          8.1                                     Elite Squad
# 37           8.6                         Raiders of the Lost Ark
# ...

# %%
movies[movies.actors_list.str.contains('Leonardo DiCaprio')]
# Out:
#      star_rating                        title content_rating      genre  \
# 11           8.8                    Inception          PG-13     Action
# 49           8.5                 The Departed              R      Crime
# 59           8.5             Django Unchained              R    Western
# 143          8.2      The Wolf of Wall Street              R  Biography
# 244          8.1               Shutter Island              R    Mystery
# 309          8.0                Blood Diamond              R  Adventure
# 340          8.0          Catch Me If You Can          PG-13  Biography
# 562          7.8  What's Eating Gilbert Grape          PG-13      Drama
# 620          7.7                      Titanic          PG-13      Drama
# 828          7.5            Gangs of New York              R      Crime
# 888          7.5                  The Aviator          PG-13  Biography
#
#      duration                                        actors_list
# ...

# %%
movies[movies.actors_list.str.contains('Leonardo DiCaprio')].sort_values(['star_rating','duration'], ascending = (True, False))
# Out:
#      star_rating                        title content_rating      genre  \
# 888          7.5                  The Aviator          PG-13  Biography
# 828          7.5            Gangs of New York              R      Crime
# 620          7.7                      Titanic          PG-13      Drama
# 562          7.8  What's Eating Gilbert Grape          PG-13      Drama
# 309          8.0                Blood Diamond              R  Adventure
# 340          8.0          Catch Me If You Can          PG-13  Biography
# 244          8.1               Shutter Island              R    Mystery
# 143          8.2      The Wolf of Wall Street              R  Biography
# 59           8.5             Django Unchained              R    Western
# 49           8.5                 The Departed              R      Crime
# 11           8.8                    Inception          PG-13     Action
#
#      duration                                        actors_list
# ...

# %% [markdown]
# DATASET 3

# %%
ufo = pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/ufo.csv")

# %%
ufo
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
ufo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18241 entries, 0 to 18240
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   City             18216 non-null  object
#  1   Colors Reported  2882 non-null   object
#  2   Shape Reported   15597 non-null  object
#  3   State            18241 non-null  object
#  4   Time             18241 non-null  object
# dtypes: object(5)
# memory usage: 712.7+ KB

# %%
ufo.isna().sum()
# Out:
# City                  25
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %%
ufo.dropna(subset = ['City', 'Shape Reported'],how="any").shape
# Out:
# (15576, 5)

# %%
ufo.dropna(subset=['City', 'Shape Reported'], how = 'all').shape
# Out:
# (18237, 5)

# %%
ufo['Shape Reported'].value_counts()
# Out:
# LIGHT        2803
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# ROUND           2
# CRESCENT        2
# DOME            1
# PYRAMID         1
# FLARE           1
# HEXAGON         1
# Name: Shape Reported, dtype: int64

# %%
ufo['Shape Reported'].isnull().sum()
# Out:
# 2644

# %% [markdown]
# DATASET 4

# %%
drinks = pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/drinks.csv")

# %%
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
drinks.head(10)
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan              0                0              0
# 1            Albania             89              132             54
# 2            Algeria             25                0             14
# 3            Andorra            245              138            312
# 4             Angola            217               57             45
# 5  Antigua & Barbuda            102              128             45
# 6          Argentina            193               25            221
# 7            Armenia             21              179             11
# 8          Australia            261               72            212
# 9            Austria            279               75            191
#
#    total_litres_of_pure_alcohol      continent
# 0                           0.0           Asia
# 1                           4.9         Europe
# 2                           0.7         Africa
# ...

# %%
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
drinks.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
drinks.beer_servings.min()
# Out:
# 0

# %%
drinks.beer_servings.max()
# Out:
# 376

# %%
drinks.beer_servings.describe()
# Out:
# count    193.000000
# mean     106.160622
# std      101.143103
# min        0.000000
# 25%       20.000000
# 50%       76.000000
# 75%      188.000000
# max      376.000000
# Name: beer_servings, dtype: float64

# %%
drinks[drinks.continent == 'Asia'].describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count      44.000000        44.000000      44.000000
# mean       37.045455        60.840909       9.068182
# std        49.469725        84.362160      21.667034
# min         0.000000         0.000000       0.000000
# 25%         4.250000         1.000000       0.000000
# 50%        17.500000        16.000000       1.000000
# 75%        60.500000        98.000000       8.000000
# max       247.000000       326.000000     123.000000
#
#        total_litres_of_pure_alcohol
# count                     44.000000
# mean                       2.170455
# std                        2.770239
# min                        0.000000
# 25%                        0.100000
# 50%                        1.200000
# 75%                        2.425000
# max                       11.500000

# %%
drinks[drinks.continent == 'Asia'].beer_servings.agg(['mean', 'min', 'max'])
# Out:
# mean     37.045455
# min       0.000000
# max     247.000000
# Name: beer_servings, dtype: float64

# %%
drinks.groupby('continent').beer_servings.max()
# Out:
# continent
# Africa           376
# Asia             247
# Europe           361
# North America    285
# Oceania          306
# South America    333
# Name: beer_servings, dtype: int64

# %%
drinks.groupby('continent').beer_servings.min()
# Out:
# continent
# Africa            0
# Asia              0
# Europe            0
# North America     1
# Oceania           0
# South America    93
# Name: beer_servings, dtype: int64

# %%
drinks.groupby('continent').beer_servings.mean()
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %%
drinks.groupby('continent').beer_servings.agg(['mean', 'min', 'max'])
# Out:
#                      mean  min  max
# continent
# Africa          61.471698    0  376
# Asia            37.045455    0  247
# Europe         193.777778    0  361
# North America  145.434783    1  285
# Oceania         89.687500    0  306
# South America  175.083333   93  333

# %%
drinks.groupby('country').beer_servings.agg(['mean', 'min', 'max'])
# Out:
#               mean  min  max
# country
# Afghanistan    0.0    0    0
# Albania       89.0   89   89
# Algeria       25.0   25   25
# Andorra      245.0  245  245
# Angola       217.0  217  217
# ...            ...  ...  ...
# Venezuela    333.0  333  333
# Vietnam      111.0  111  111
# Yemen          6.0    6    6
# Zambia        32.0   32   32
# Zimbabwe      64.0   64   64
#
# [193 rows x 3 columns]
